# %%
from requests import Session
import json
session = Session()

# %%
#loop to iterate through observation keys and pull data from given url
#data is stored as a list in the latlong list
for i in observations:
    response = session.get('http://api.inaturalist.org/v1/observations?taxon_id=48662%2C49348%2C129362%2C68263%2C49150%2C50072%2C50931%2C48548%2C50340%2C51743&year=2016&order=desc&order_by=created_at' )
    jsonVar = json.loads(response.text)
    

print(jsonVar)
# Out:
# {'total_results': 13808, 'page': 1, 'per_page': 30, 'results': [{'out_of_range': None, 'quality_grade': 'research', 'time_observed_at': '2016-07-02T11:20:00-05:00', 'annotations': [], 'uuid': '1953a010-f224-4659-a80e-878926f349c8', 'photos': [{'attribution': '(c) Emily Hjalmarson, some rights reserved (CC BY-NC)', 'flags': [], 'id': 11179862, 'license_code': 'cc-by-nc', 'original_dimensions': {'width': 589, 'height': 492}, 'url': 'https://static.inaturalist.org/photos/11179862/square.jpeg?1508009774'}], 'observed_on_details': {'date': '2016-07-02', 'week': 26, 'month': 7, 'hour': 11, 'year': 2016, 'day': 2}, 'id': 8402634, 'cached_votes_total': 0, 'identifications_most_agree': True, 'created_at_details': {'date': '2017-10-14', 'week': 41, 'month': 10, 'hour': 14, 'year': 2017, 'day': 14}, 'species_guess': 'Gray Hairstreak', 'identifications_most_disagree': False, 'tags': ['ABQ Botanic Gardens'], 'positional_accuracy': 225, 'comments_count': 0, 'site_id': 1, 'created_time_zone': 'Amer
# ...
